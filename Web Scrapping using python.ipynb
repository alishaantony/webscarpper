# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://gaana.com/"

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="notranslate" lang="en" translate="no">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, " name="viewport"/>
#   <meta content="#222428" name="theme-color"/>
#   <meta content="Isu9IQakMXodVZHO_6tV6DUNWSRF7s9I5FY-_lLKqNA" name="google-site-verification"/>
#   <link href="https://a10.gaanacdn.com/images/gaanawebsite/Gaana_logo_192.png" rel="apple-touch-icon"/>
#   <title>
#    Download Latest MP3 Songs Online: Play Old &amp; New MP3 Music Online Free on Gaana.com
#   </title>
#   <meta content="Gaana.com- Listen &amp; Download latest MP3 songs online. Download new or old Hindi songs, Bollywood songs, English songs* &amp; more on Gaana+ and play offline. Create, share and listen to streaming music playlists for free." data-react-helmet="true" name="description"/>
# ...
